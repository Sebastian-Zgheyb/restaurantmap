# %%
import requests
import json

url = "http://127.0.0.1:8000/get_data"  # Adjust if needed
payload = {
    "latitude": -33.88551073206512,
    "longitude": 151.20003137840553,
    "radius": 500
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print("Raw Response:", response.text)  # <-- Check this before calling .json()

try:
    response_data = response.json()  # This might fail
    print("Response JSON:", response_data)
    
    # Dump the response data to a JSON file
    with open('response_data.json', 'w') as json_file:
        json.dump(response_data, json_file, indent=4)
    print("Data has been written to 'response_data.json'.")

except requests.exceptions.JSONDecodeError:
    print("Error: Response is not valid JSON")
# Out:
# Status Code: 200
# Raw Response: {"places":[{"id":"ChIJ6zKDW9axEmsRATN9DcxvROM","latitude":-33.8875972,"longitude":151.19471389999998,"name":"The Duck Inn Pub & Kitchen","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"40"},"startPrice":{"currencyCode":"AUD","units":"20"}},"rating":4.1,"types":["pub","bar","point_of_interest","establishment"]},{"id":"ChIJmdfIvCmuEmsRD3b3UoWDNjk","latitude":-33.8837198,"longitude":151.19477,"name":"Off Broadway Hotel","priceLevel":"PRICE_LEVEL_INEXPENSIVE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"40"},"startPrice":{"currencyCode":"AUD","units":"20"}},"rating":4,"types":["bar","point_of_interest","establishment"]},{"id":"ChIJl6SBsSmvEmsRAP5zlNux8W8","latitude":-33.883708299999995,"longitude":151.19480149999998,"name":"Mae - Ong Thai @Broadway","priceLevel":null,"priceRange":{"endPrice":{"currencyCode":"AUD","units":"20"},"startPrice":{"currencyCode":"AUD","units":"1"}},"rating":4.3,"types":["thai_restaurant","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJ7aKzuimuEmsRsxTrDlarzHU","latitude":-33.8837981,"longitude":151.19474259999998,"name":"Merchants of Ultimo","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"40"},"startPrice":{"currencyCode":"AUD","units":"20"}},"rating":4,"types":["restaurant","hamburger_restaurant","vegan_restaurant","vegetarian_restaurant","american_restaurant","dessert_shop","confectionery","breakfast_restaurant","pizza_restaurant","point_of_interest","bakery","food_store","store","food","establishment"]},{"id":"ChIJB9EgNHuvEmsRoPT5so-CQqk","latitude":-33.8837012,"longitude":151.1943997,"name":"KFC","priceLevel":"PRICE_LEVEL_INEXPENSIVE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"20"},"startPrice":{"currencyCode":"AUD","units":"1"}},"rating":2.2,"types":["fast_food_restaurant","meal_takeaway","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJS1hJqa-vEmsRosxiZ9qX69I","latitude":-33.8837013,"longitude":151.1943992,"name":"Starbucks Broadway","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"20"},"startPrice":{"currencyCode":"AUD","units":"1"}},"rating":3.2,"types":["coffee_shop","cafe","point_of_interest","food_store","store","food","establishment"]},{"id":"ChIJjyFXfyiuEmsR3erhK_wZMLY","latitude":-33.8837511,"longitude":151.1948086,"name":"Boost Juice Broadway","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"20"},"startPrice":{"currencyCode":"AUD","units":"1"}},"rating":2.7,"types":["juice_shop","point_of_interest","food","establishment"]},{"id":"ChIJw5XiqYCvEmsRZ09gBmmcuwo","latitude":-33.8837013,"longitude":151.1943992,"name":"Motto Motto Japanese Kitchen - Broadway","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"20"},"startPrice":{"currencyCode":"AUD","units":"1"}},"rating":4.7,"types":["japanese_restaurant","ramen_restaurant","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJN6tMo52vEmsRgVAl-y_TZDU","latitude":-33.8837013,"longitude":151.1943992,"name":"Acai Bowls Sydney","priceLevel":null,"priceRange":{"endPrice":{"currencyCode":"AUD","units":"20"},"startPrice":{"currencyCode":"AUD","units":"1"}},"rating":4.1,"types":["acai_shop","brazilian_restaurant","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJdWZAuymuEmsRwl1B66cPU9M","latitude":-33.8837012,"longitude":151.1943997,"name":"Zeus Street Greek Broadway Sydney","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"AUD","units":"40"},"startPrice":{"currencyCode":"AUD","units":"20"}},"rating":3.9,"types":["greek_restaurant","catering_service","food_delivery","meal_takeaway","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJS1VVlSiuEmsRiSmahXKNdX0","latitude":-33.8837013,"longitude":151.1943992,"name":"Schnitz Broadway","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice": ...
#
# Response JSON: {'places': [{'id': 'ChIJ6zKDW9axEmsRATN9DcxvROM', 'latitude': -33.8875972, 'longitude': 151.19471389999998, 'name': 'The Duck Inn Pub & Kitchen', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '40'}, 'startPrice': {'currencyCode': 'AUD', 'units': '20'}}, 'rating': 4.1, 'types': ['pub', 'bar', 'point_of_interest', 'establishment']}, {'id': 'ChIJmdfIvCmuEmsRD3b3UoWDNjk', 'latitude': -33.8837198, 'longitude': 151.19477, 'name': 'Off Broadway Hotel', 'priceLevel': 'PRICE_LEVEL_INEXPENSIVE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '40'}, 'startPrice': {'currencyCode': 'AUD', 'units': '20'}}, 'rating': 4, 'types': ['bar', 'point_of_interest', 'establishment']}, {'id': 'ChIJl6SBsSmvEmsRAP5zlNux8W8', 'latitude': -33.883708299999995, 'longitude': 151.19480149999998, 'name': 'Mae - Ong Thai @Broadway', 'priceLevel': None, 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '20'}, 'startPrice': {'currencyCode': 'AUD', 'units': '1'}}, 'rating': 4.3, 'types': ['thai_restaurant', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJ7aKzuimuEmsRsxTrDlarzHU', 'latitude': -33.8837981, 'longitude': 151.19474259999998, 'name': 'Merchants of Ultimo', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '40'}, 'startPrice': {'currencyCode': 'AUD', 'units': '20'}}, 'rating': 4, 'types': ['restaurant', 'hamburger_restaurant', 'vegan_restaurant', 'vegetarian_restaurant', 'american_restaurant', 'dessert_shop', 'confectionery', 'breakfast_restaurant', 'pizza_restaurant', 'point_of_interest', 'bakery', 'food_store', 'store', 'food', 'establishment']}, {'id': 'ChIJB9EgNHuvEmsRoPT5so-CQqk', 'latitude': -33.8837012, 'longitude': 151.1943997, 'name': 'KFC', 'priceLevel': 'PRICE_LEVEL_INEXPENSIVE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '20'}, 'startPrice': {'currencyCode': 'AUD', 'units': '1'}}, 'rating': 2.2, 'types': ['fast_food_restaurant', 'meal_takeaway', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJS1hJqa-vEmsRosxiZ9qX69I', 'latitude': -33.8837013, 'longitude': 151.1943992, 'name': 'Starbucks Broadway', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '20'}, 'startPrice': {'currencyCode': 'AUD', 'units': '1'}}, 'rating': 3.2, 'types': ['coffee_shop', 'cafe', 'point_of_interest', 'food_store', 'store', 'food', 'establishment']}, {'id': 'ChIJjyFXfyiuEmsR3erhK_wZMLY', 'latitude': -33.8837511, 'longitude': 151.1948086, 'name': 'Boost Juice Broadway', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '20'}, 'startPrice': {'currencyCode': 'AUD', 'units': '1'}}, 'rating': 2.7, 'types': ['juice_shop', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJw5XiqYCvEmsRZ09gBmmcuwo', 'latitude': -33.8837013, 'longitude': 151.1943992, 'name': 'Motto Motto Japanese Kitchen - Broadway', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '20'}, 'startPrice': {'currencyCode': 'AUD', 'units': '1'}}, 'rating': 4.7, 'types': ['japanese_restaurant', 'ramen_restaurant', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJN6tMo52vEmsRgVAl-y_TZDU', 'latitude': -33.8837013, 'longitude': 151.1943992, 'name': 'Acai Bowls Sydney', 'priceLevel': None, 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '20'}, 'startPrice': {'currencyCode': 'AUD', 'units': '1'}}, 'rating': 4.1, 'types': ['acai_shop', 'brazilian_restaurant', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJdWZAuymuEmsRwl1B66cPU9M', 'latitude': -33.8837012, 'longitude': 151.1943997, 'name': 'Zeus Street Greek Broadway Sydney', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'AUD', 'units': '40'}, 'startPrice': {'currencyCode': 'AUD', 'units': '20'}}, 'rating': 3.9, 'types': [ ...
# Data has been written to 'response_data.json'.
