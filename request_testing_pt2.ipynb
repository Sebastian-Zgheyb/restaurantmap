# %%
import requests

url = "http://127.0.0.1:8000/get_data"  # Adjust if needed
payload = {
    "latitude": 37.7749,
    "longitude": -122.4194,
    "radius": 500
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print("Raw Response:", response.text)  # <-- Check this before calling .json()

try:
    response_data = response.json()  # This might fail
    print("Response JSON:", response_data)
except requests.exceptions.JSONDecodeError:
    print("Error: Response is not valid JSON")
# Out:
# Status Code: 200
# Raw Response: {"places":[{"id":"ChIJZ_Ak36GAhYARaz2iDa2Cygs","latitude":37.7739809,"longitude":-122.42425340000001,"name":"Mercury Cafe","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"20"},"startPrice":{"currencyCode":"USD","units":"10"}},"rating":4.3,"types":["cafe","sandwich_shop","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJj61NN6KAhYARMWDXrggZTH8","latitude":37.775623599999996,"longitude":-122.42623879999998,"name":"Il Borgo","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"30"},"startPrice":{"currencyCode":"USD","units":"20"}},"rating":4.3,"types":["italian_restaurant","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJbTB3bKKAhYAR8Yqc6dEIMbQ","latitude":37.776525,"longitude":-122.42500280000002,"name":"Souvla","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"20"},"startPrice":{"currencyCode":"USD","units":"10"}},"rating":4.5,"types":["greek_restaurant","restaurant","food","point_of_interest","establishment"]},{"id":"ChIJr6l20DWBhYARjabnlV9lI0o","latitude":37.7712462,"longitude":-122.4238573,"name":"Curry Hyuga","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"30"},"startPrice":{"currencyCode":"USD","units":"20"}},"rating":4.7,"types":["restaurant","point_of_interest","food","establishment"]},{"id":"ChIJh_24QJ-AhYAR_xbUNVN2Xns","latitude":37.7748657,"longitude":-122.4228497,"name":"Rich Table","priceLevel":"PRICE_LEVEL_EXPENSIVE","priceRange":{"startPrice":{"currencyCode":"USD","units":"100"}},"rating":4.7,"types":["american_restaurant","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJlYL0Wa-BhYARJi6qr49Ncv0","latitude":37.7758205,"longitude":-122.42263609999998,"name":"Dumpling Home","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"50"},"startPrice":{"currencyCode":"USD","units":"30"}},"rating":4.6,"types":["chinese_restaurant","meal_takeaway","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJjfhunpiAhYARL76pNCCCFvg","latitude":37.7768993,"longitude":-122.4240297,"name":"a Mano","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"50"},"startPrice":{"currencyCode":"USD","units":"30"}},"rating":4.4,"types":["italian_restaurant","wine_bar","bar","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJ-7YMCl6BhYAR5jZSEDs5_SE","latitude":37.7777216,"longitude":-122.42299000000001,"name":"Teakwood","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"50"},"startPrice":{"currencyCode":"USD","units":"30"}},"rating":4.3,"types":["asian_restaurant","bar","seafood_restaurant","restaurant","food","point_of_interest","establishment"]},{"id":"ChIJU889QiB-j4ARzQofqaFrMJU","latitude":37.770022999999995,"longitude":-122.42211719999999,"name":"Zeitgeist","priceLevel":"PRICE_LEVEL_INEXPENSIVE","priceRange":{"endPrice":{"currencyCode":"USD","units":"20"},"startPrice":{"currencyCode":"USD","units":"10"}},"rating":4.3,"types":["bar","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJO7u9q5-AhYARiSSXyWv9eJ8","latitude":37.7736,"longitude":-122.42160799999999,"name":"Zuni Caf\u00e9","priceLevel":"PRICE_LEVEL_EXPENSIVE","priceRange":{"endPrice":{"currencyCode":"USD","units":"100"},"startPrice":{"currencyCode":"USD","units":"50"}},"rating":4.4,"types":["wine_bar","italian_restaurant","cafe","american_restaurant","bar","restaurant","point_of_interest","food","establishment"]},{"id":"ChIJc-rRpmSBhYARllfwwCjG7r0","latitude":37.7769287,"longitude":-122.42157420000001,"name":"Rad Radish","priceLevel":"PRICE_LEVEL_MODERATE","priceRange":{"endPrice":{"currencyCode":"USD","units":"20"},"startPrice":{"currencyCode":"USD","units":"10"}},"rating":4.5,"types":["vegan_restaurant","vegetarian_restaurant","restaurant","point_of_interest","food","establishment"] ...
#
# Response JSON: {'places': [{'id': 'ChIJZ_Ak36GAhYARaz2iDa2Cygs', 'latitude': 37.7739809, 'longitude': -122.42425340000001, 'name': 'Mercury Cafe', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '20'}, 'startPrice': {'currencyCode': 'USD', 'units': '10'}}, 'rating': 4.3, 'types': ['cafe', 'sandwich_shop', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJj61NN6KAhYARMWDXrggZTH8', 'latitude': 37.775623599999996, 'longitude': -122.42623879999998, 'name': 'Il Borgo', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '30'}, 'startPrice': {'currencyCode': 'USD', 'units': '20'}}, 'rating': 4.3, 'types': ['italian_restaurant', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJbTB3bKKAhYAR8Yqc6dEIMbQ', 'latitude': 37.776525, 'longitude': -122.42500280000002, 'name': 'Souvla', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '20'}, 'startPrice': {'currencyCode': 'USD', 'units': '10'}}, 'rating': 4.5, 'types': ['greek_restaurant', 'restaurant', 'food', 'point_of_interest', 'establishment']}, {'id': 'ChIJr6l20DWBhYARjabnlV9lI0o', 'latitude': 37.7712462, 'longitude': -122.4238573, 'name': 'Curry Hyuga', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '30'}, 'startPrice': {'currencyCode': 'USD', 'units': '20'}}, 'rating': 4.7, 'types': ['restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJh_24QJ-AhYAR_xbUNVN2Xns', 'latitude': 37.7748657, 'longitude': -122.4228497, 'name': 'Rich Table', 'priceLevel': 'PRICE_LEVEL_EXPENSIVE', 'priceRange': {'startPrice': {'currencyCode': 'USD', 'units': '100'}}, 'rating': 4.7, 'types': ['american_restaurant', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJlYL0Wa-BhYARJi6qr49Ncv0', 'latitude': 37.7758205, 'longitude': -122.42263609999998, 'name': 'Dumpling Home', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '50'}, 'startPrice': {'currencyCode': 'USD', 'units': '30'}}, 'rating': 4.6, 'types': ['chinese_restaurant', 'meal_takeaway', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJjfhunpiAhYARL76pNCCCFvg', 'latitude': 37.7768993, 'longitude': -122.4240297, 'name': 'a Mano', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '50'}, 'startPrice': {'currencyCode': 'USD', 'units': '30'}}, 'rating': 4.4, 'types': ['italian_restaurant', 'wine_bar', 'bar', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJ-7YMCl6BhYAR5jZSEDs5_SE', 'latitude': 37.7777216, 'longitude': -122.42299000000001, 'name': 'Teakwood', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '50'}, 'startPrice': {'currencyCode': 'USD', 'units': '30'}}, 'rating': 4.3, 'types': ['asian_restaurant', 'bar', 'seafood_restaurant', 'restaurant', 'food', 'point_of_interest', 'establishment']}, {'id': 'ChIJU889QiB-j4ARzQofqaFrMJU', 'latitude': 37.770022999999995, 'longitude': -122.42211719999999, 'name': 'Zeitgeist', 'priceLevel': 'PRICE_LEVEL_INEXPENSIVE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '20'}, 'startPrice': {'currencyCode': 'USD', 'units': '10'}}, 'rating': 4.3, 'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJO7u9q5-AhYARiSSXyWv9eJ8', 'latitude': 37.7736, 'longitude': -122.42160799999999, 'name': 'Zuni Café', 'priceLevel': 'PRICE_LEVEL_EXPENSIVE', 'priceRange': {'endPrice': {'currencyCode': 'USD', 'units': '100'}, 'startPrice': {'currencyCode': 'USD', 'units': '50'}}, 'rating': 4.4, 'types': ['wine_bar', 'italian_restaurant', 'cafe', 'american_restaurant', 'bar', 'restaurant', 'point_of_interest', 'food', 'establishment']}, {'id': 'ChIJc-rRpmSBhYARllfwwCjG7r0', 'latitude': 37.7769287, 'longitude': -122.4215742 ...
